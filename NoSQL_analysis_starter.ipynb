# %% [markdown]
# # Eat Safe, Love

# %% [markdown]
# ## Notebook Set Up

# %%
# Import dependencies
from pymongo import MongoClient
from pprint import pprint
import pandas as pd

# %%
# Create an instance of MongoClient
mongo = MongoClient(port=27017)

# %%
# assign the uk_food database to a variable name
db = mongo['uk_food']

# %%
# review the collections in our database
db.list_collection_names()
# Out:
# ['establishments']

# %%
# assign the collection to a variable
establishments = db['establishments']

# %% [markdown]
# ## Part 3: Exploratory Analysis
# Unless otherwise stated, for each question:
# * Use `count_documents` to display the number of documents contained in the result.
# * Display the first document in the results using `pprint`.
# * Convert the result to a Pandas DataFrame, print the number of rows in the DataFrame, and display the first 10 rows.

# %% [markdown]
# ### 1. Which establishments have a hygiene score equal to 20?

# %%
# Find the establishments with a hygiene score of 20
query = {'scores.Hygiene':{"$eq":20}}

# Use count_documents to display the number of documents in the result
print("Number of documents in result:", establishments.count_documents(query))

# Display the first document in the results using pprint
result = list(establishments.find(query))

result[1]
# Out:
# Number of documents in result: 41
# {'_id': ObjectId('64af697ffae119709836e93f'),
#  'FHRSID': 612039,
#  'ChangesByServerID': 0,
#  'LocalAuthorityBusinessID': '1970/FOOD',
#  'BusinessName': 'Brenalwood',
#  'BusinessType': 'Caring Premises',
#  'BusinessTypeID': 5,
#  'AddressLine1': 'Hall Lane',
#  'AddressLine2': 'Walton-on-the-Naze',
#  'AddressLine3': 'Essex',
#  'AddressLine4': '',
#  'PostCode': 'CO14 8HN',
#  'Phone': '',
#  'RatingValue': None,
#  'RatingKey': 'fhrs_0_en-gb',
#  'RatingDate': '2022-06-22T00:00:00',
#  'LocalAuthorityCode': '120',
#  'LocalAuthorityName': 'Tendring',
#  'LocalAuthorityWebSite': 'http://www.tendringdc.gov.uk/',
#  'LocalAuthorityEmailAddress': 'fhsadmin@tendringdc.gov.uk',
#  'scores': {'Hygiene': 20, 'Structural': 15, 'ConfidenceInManagement': 30},
#  'SchemeType': 'FHRS',
#  'geocode': {'longitude': 1.278721, 'latitude': 51.857536},
#  'RightToReply': '',
#  'Distance': 4617.965823673803,
#  'NewRatingPending': False,
#  'meta': {'dataSource': None,
#   'extractDate': '0001-01-01T00:00:00',
#   'itemCount': 0,
#   'returncode': None,
#   'totalCount': 0,
#   'totalPages': 0,
#   'pageSize': 0,
#   'pageNumber': 0},
#  'links': [{'rel': 'self',
#    'href': 'https://api.ratings.food.gov.uk/establishments/612039'}]}

# %%
# Convert the result to a Pandas DataFrame
df = pd.json_normalize(result)
# Display the number of rows in the DataFrame
print("Number of rows in result: ", len(df))
# Display the first 10 rows of the DataFrame
df.head(10)
# Out:
# Number of rows in result:  41
#                         _id   FHRSID  ...  meta.pageSize meta.pageNumber
# 0  64ad97547fe3f17650016854   110681  ...              0               0
# 1  64ad97547fe3f17650016bd9   612039  ...              0               0
# 2  64ad97547fe3f17650016eda   730933  ...              0               0
# 3  64ad97547fe3f176500170cb   172735  ...              0               0
# 4  64ad97547fe3f176500170db   172953  ...              0               0
# 5  64ad97547fe3f17650017a7a   512854  ...              0               0
# 6  64ad97547fe3f17650017c97  1537089  ...              0               0
# 7  64ad97547fe3f176500191c7   155648  ...              0               0
# 8  64ad97547fe3f1765001960a  1012883  ...              0               0
# 9  64ad97547fe3f17650019e1a   644109  ...              0               0
#
# [10 rows x 38 columns]

# %% [markdown]
# ### 2. Which establishments in London have a `RatingValue` greater than or equal to 4?

# %%
# Find the establishments with London as the Local Authority and has a RatingValue greater than or equal to 4.
query = {"LocalAuthorityName":{"$regex":"London"},"RatingValue":{"$gte": 4}}

# Use count_documents to display the number of documents in the result
print("Number of documents in result:", establishments.count_documents(query))

# Display the first document in the results using pprint
result = list(establishments.find(query))

result[1]
# Out:
# Number of documents in result: 33
# {'_id': ObjectId('64af6980fae11970983702fe'),
#  'FHRSID': 1130836,
#  'ChangesByServerID': 0,
#  'LocalAuthorityBusinessID': 'PI/000034075',
#  'BusinessName': 'Mv City Cruises Erasmus',
#  'BusinessType': 'Other catering premises',
#  'BusinessTypeID': 7841,
#  'AddressLine1': 'Cherry Garden Pier',
#  'AddressLine2': 'Cherry Garden Street Rotherhithe',
#  'AddressLine3': 'Charlton',
#  'AddressLine4': '',
#  'PostCode': 'TN4 8HR',
#  'Phone': '',
#  'RatingValue': 5,
#  'RatingKey': 'fhrs_5_en-gb',
#  'RatingDate': '2021-05-14T00:00:00',
#  'LocalAuthorityCode': '508',
#  'LocalAuthorityName': 'City of London Corporation',
#  'LocalAuthorityWebSite': 'http://www.cityoflondon.gov.uk/Corporation/homepage.htm',
#  'LocalAuthorityEmailAddress': 'publicprotection@cityoflondon.gov.uk',
#  'scores': {'Hygiene': 0, 'Structural': 5, 'ConfidenceInManagement': 0},
#  'SchemeType': 'FHRS',
#  'geocode': {'longitude': 0.249255999922752, 'latitude': 51.1236228942871},
#  'RightToReply': '',
#  'Distance': 4627.8731788858,
#  'NewRatingPending': False,
#  'meta': {'dataSource': None,
#   'extractDate': '0001-01-01T00:00:00',
#   'itemCount': 0,
#   'returncode': None,
#   'totalCount': 0,
#   'totalPages': 0,
#   'pageSize': 0,
#   'pageNumber': 0},
#  'links': [{'rel': 'self',
#    'href': 'http://api.ratings.food.gov.uk/establishments/1130836'}]}

# %%
# Convert the result to a Pandas DataFrame
df2 = pd.json_normalize(result)
# Display the number of rows in the DataFrame
print("Number of rows in result: ", len(df2))
# Display the first 10 rows of the DataFrame
df2.head(10)
# Out:
# Number of rows in result:  33
#                         _id   FHRSID  ...  meta.pageSize meta.pageNumber
# 0  64af6980fae119709836ffdc   621707  ...              0               0
# 1  64af6980fae11970983702fe  1130836  ...              0               0
# 2  64af6980fae1197098370e4e   293783  ...              0               0
# 3  64af6980fae1197098371c50  1315095  ...              0               0
# 4  64af6980fae1197098371c52   294474  ...              0               0
# 5  64af6980fae1197098372353   294900  ...              0               0
# 6  64af6980fae1197098374463   293756  ...              0               0
# 7  64af6980fae1197098374829   878523  ...              0               0
# 8  64af6980fae1197098374843   294606  ...              0               0
# 9  64af6980fae1197098374844   293772  ...              0               0
#
# [10 rows x 38 columns]

# %% [markdown]
# ### 3. What are the top 5 establishments with a `RatingValue` rating value of 5, sorted by lowest hygiene score, nearest to the new restaurant added, "Penang Flavours"?

# %%
# Search within 0.01 degree on either side of the latitude and longitude.
# Rating value must equal 5
# Sort by hygiene score

degree_search = 0.01
latitude = establishments.find_one({"BusinessName" : "Penang Flavours"})["geocode"]["latitude"]
longitude = establishments.find_one({"BusinessName" : "Penang Flavours"})["geocode"]["longitude"]

# Construct the query
query = {
    "RatingValue": 5,
    "geocode.latitude": {"$gte": latitude - degree_search, "$lte": latitude + degree_search},
    "geocode.longitude": {"$gte": longitude - degree_search, "$lte": longitude + degree_search}
}

# Sort by lowest hygiene score
sort = [("scores.Hygiene", 1)]

# Find the top 5 establishments
result =list(establishments.find(query).sort(sort).limit(5))

# %%
# Convert result to Pandas DataFrame
df3 = pd.json_normalize(result)
df3
# Out:
#                         _id   FHRSID  ...  meta.pageSize meta.pageNumber
# 0  64b07223767633d894d8aebf  1380578  ...              0               0
# 1  64b07223767633d894d8aef6   694478  ...              0               0
# 2  64b07223767633d894d8aef4   695241  ...              0               0
# 3  64b07223767633d894d8aead   695223  ...              0               0
# 4  64b07223767633d894d8aedc   694609  ...              0               0
#
# [5 rows x 38 columns]

# %% [markdown]
# ### 4. How many establishments in each Local Authority area have a hygiene score of 0?

# %%
# Create a pipeline that: 
# 1. Matches establishments with a hygiene score of 0
# 2. Groups the matches by Local Authority
# 3. Sorts the matches from highest to lowest

pipeline = [
    {"$match": {"scores.Hygiene": 0}},
    {"$group": {"_id": "$LocalAuthorityName", "count": {"$sum": 1}}},
    {"$sort": {"count": -1}}
]

# Execute the pipeline and retrieve the results
result = list(establishments.aggregate(pipeline))

# Print the number of documents in the result
print("Number of documents in the result:", len(result))

# Print the first 10 results
print("First 10 results:")
for i in range(10):
    pprint(result[i])
# Out:
# Number of documents in the result: 55
# First 10 results:
# {'_id': 'Thanet', 'count': 1130}
# {'_id': 'Greenwich', 'count': 882}
# {'_id': 'Maidstone', 'count': 713}
# {'_id': 'Newham', 'count': 711}
# {'_id': 'Swale', 'count': 686}
# {'_id': 'Chelmsford', 'count': 680}
# {'_id': 'Medway', 'count': 672}
# {'_id': 'Bexley', 'count': 607}
# {'_id': 'Southend-On-Sea', 'count': 586}
# {'_id': 'Tendring', 'count': 542}

# %%
# Convert the result to a Pandas DataFrame
df4 = pd.DataFrame(result)

# Display the number of rows in the DataFrame
print("Number of rows in the DataFrame:", len(df4))

# Display the first 10 rows of the DataFrame
print("First 10 rows of the DataFrame:")
print(df4.head(10))
# Out:
# Number of rows in the DataFrame: 55
# First 10 rows of the DataFrame:
#                _id  count
# 0           Thanet   1130
# 1        Greenwich    882
# 2        Maidstone    713
# 3           Newham    711
# 4            Swale    686
# 5       Chelmsford    680
# 6           Medway    672
# 7           Bexley    607
# 8  Southend-On-Sea    586
# 9         Tendring    542
